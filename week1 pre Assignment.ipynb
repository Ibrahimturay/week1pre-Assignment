# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS*2**43
print("Thickness: {} meters=".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters=

# %%
folded_thickness = 100000
print("converted unit in kilometers =", folded_thickness)
# Out:
# converted unit in kilometers = 100000

# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2*2
print("thinkness:{:.2f}km". format (folded_thickness/10000))
# Out:
# thinkness:70368.74km

# %%
import time
start = time.time()
#####
folded_thickness = THICKNESS*(2**43)
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time*1000))
# Out:
# time : 0.0[s]

# %%
#####
folded_thickness = THICKNESS
for i in range (n_folded):
    folded_thickness = folded_thickness*2
#####
elapsed_time = time.time() - start
print("time : {}[ms]".format(elapsed_time*1000))
# Out:
# time : 386769.1283226013[ms]

# %%
THICKNESS = 0.00008

n_folded = 43
folded_thickness_list.append(folded_thickness_list[-1]*2)
print("thinkness:{:.2f}km" .format(folded_thickness_list[-1]))
print("......")
print("THICKNESS")
print(folded_thickness_list)
# Out:
# thinkness:0.00km
# ......
# THICKNESS
# [8e-05, 0.00016]

# %%
# draw a line graph

plt. title("thickness of folded")
plt. ylabel("number of folds")
plt.ylabel("thinkness[m]")
plt.plot(folded_thickness_list)
plt.show()

# %%
# change the color of the line

plt. title("thickness of folded")
plt. ylabel("number of folds")
plt.ylabel("thinkness[m]")
plt.plot(folded_thickness_list, color = "yellow")
plt.show()

# %%
# Insert a marker
plt. title("thickness of folded")
plt. ylabel("number of folds")
plt.ylabel("thinkness[m]")
plt.plot(folded_thickness_list, marker='o')
plt.show()
